# %% [markdown]
# <a href="https://colab.research.google.com/github/shimohiro/EU_M_Math-Repository/blob/master/Chap08_Ex_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mkdir chap8Ex

# %%
cd ./chap8Ex
# Out:
# /content/chap8Ex

# %%
#練習問題1
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import requests, zipfile
import io
from io import StringIO

url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data'
res = requests.get(url)
data_text = res.text

auto = pd.read_csv(io.StringIO(data_text), header=None)

auto.columns = ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
                'engine-size','fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %%
auto.head()
# Out:
#    symboling normalized-losses         make fuel-type  ... peak-rpm city-mpg highway-mpg  price
# 0          3                 ?  alfa-romero       gas  ...     5000       21          27  13495
# 1          3                 ?  alfa-romero       gas  ...     5000       21          27  16500
# 2          1                 ?  alfa-romero       gas  ...     5000       19          26  16500
# 3          2               164         audi       gas  ...     5500       24          30  13950
# 4          2               164         audi       gas  ...     5500       18          22  17450
#
# [5 rows x 26 columns]

# %%
auto = auto[['price','width','engine-size']]
auto.isin(['?']).sum()
# Out:
# price          4
# width          0
# engine-size    0
# dtype: int64

# %%
auto = auto.replace('?', np.nan).dropna()
auto.shape
print('自動車データの形式：{}'.format(auto.shape))
# Out:
# 自動車データの形式：(201, 3)

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

X = auto.drop('price', axis = 1)
y = auto['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

model = LinearRegression()
model.fit(X_train,y_train)

print('決定係数(train):{:.3f}'.format(model.score(X_train,y_train)))
print('決定係数(test):{:.3f}'.format(model.score(X_test,y_test)))

print('\n回数回帰\n{}'.format(pd.Series(model.coef_, index = X.columns)))
print('切片: {:.3f}'.format(model.intercept_))
# Out:
# 決定係数(train):0.783
# 決定係数(test):0.778
#
# 回数回帰
# width          1261.735518
# engine-size     109.526787
# dtype: float64
# 切片: -84060.643
