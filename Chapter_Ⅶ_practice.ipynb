# %% [markdown]
# <a href="https://colab.research.google.com/github/shimohiro/EU_M_Math-Repository/blob/master/Chapter_%E2%85%A6_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set()
# %matplotlib inline

# %precision 3
# Out:
# '%.3f'

# %%
x = [1, 2, 3]
y = [10, 1, 4]

plt.figure(figsize=(10,6))

plt.bar(x, y, align='center', width = 0.5)

plt.xticks(x, ['A Class', 'B Class', 'C Class'])

plt.xlabel('Class')
plt.ylabel('Score')

plt.grid(True)

# %%
x = [1, 2, 3]
y = [10, 1, 4]

plt.figure(figsize=(10, 6))

plt.barh(x, y, align = 'center')
plt.yticks(x, ['A Class','B Class', 'C Class'])
plt.ylabel('Class')
plt.xlabel('Score')
plt.grid(True)

# %%
y1 = np.array([30, 10,40])
y2 = np.array([10, 50, 90])

x = np.arange(len(y1))

w = 0.4

plt.figure(figsize=(10, 6))

plt.bar(x, y1, color = 'blue', width = w, label = 'Math first', align = 'center')
plt.bar(x + w, y2, color = 'green', width = w, label = 'Math final', align = 'center')

plt.legend(x + w / 2, ['Class A', 'Class B', 'Class C'])
plt.grid(True)
# Out:
# <ipython-input-5-c75551490a38>:13: UserWarning:
#
# Legend does not support handles for float64 instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#controlling-the-legend-entries

# %%
height1 = np.array([100, 200, 300, 400, 500])
height2 = np.array([1000, 800, 600, 400, 200])

x = np.array([1, 2, 3, 4, 5])

plt.figure(figsize = (10, 6))

p1 = plt.bar(x, height1, color = 'blue')
p2 = plt.bar(x, height2, bottom = height1, color = 'lightblue')

plt.legend((p1[0], p2[0]), ('Class A', 'Class B'))

# %%
labels = ['Frogs', 'Hogs', 'Dogs', 'Logs']
size = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0.1, 0, 0)

plt.figure(figsize = (15, 6))

plt.pie(size, explode = explode, labels = labels, colors = colors, autopct = '%1.1f%%', shadow = True, startangle = 90)

plt.axis('equal')
# Out:
# (-1.1998593997207165,
#  1.1047438740833693,
#  -1.0999843660947275,
#  1.0999992555283205)

# %%
N = 25

x = np.random.rand(N)
y = np.random.rand(N)

colors = np.random.rand(N)

area = 10 * np.pi * (15 * np.random.rand(N)) ** 2

plt.figure(figsize = (15, 6))

plt.scatter(x, y, s = area, c = colors, alpha = 0.5)
plt.grid(True)

# %%
idx = pd.date_range('2015/01/01', '2015/12/31 23:59', freq='T')

dn = np.random.randint(2, size = len(idx)) * 2 - 1
rnd_walk = np.cumprod(np.exp(dn * 0.0002)) * 100

df = pd.Series(rnd_walk, index = idx).resample('B').ohlc()

# %%
df.plot(figsize = (15, 6), legend = 'best', grid = True)
# Out:
# <Axes: >

# %%
import plotly
from plotly.offline import init_notebook_mode, iplot
from plotly import figure_factory as FF
from plotly.graph_objs import Scatter, Layout

plotly.offline.init_notebook_mode(connected=True)

init_notebook_mode(connected=True)

fig = FF.create_candlestick(df.open, df.high, df.low, df.close, dates = df.index)
fig.show(renderer='colab')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="85221bb6-66d4-4681-9299-511f37466927" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85221bb6-66d4-4681-9299-511f37466927")) {                    Plotly.newPlot(                        "85221bb6-66d4-4681-9299-511f37466927",                        [{"boxpoints":false,"fillcolor":"#3D9970","line":{"color":"#3D9970"},"name":"Increasing","showlegend":false,"whiskerwidth":0,"x":["2015-01-01T00:00:00","2015-01-01T00:00:00","2015-01-01T00:00:00","2015-01-01T00:00:00","2015-01-01T00:00:00","2015-01-01T00:00:00","2015-01-05T00:00:00","2015-01-05T00:00:00","2015-01-05T00:00:00","2015-01-05T00:00:00","2015-01-05T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-06T00:00:00","2015-01-06T00:00:00","2015-01-06T00:00:00","2015-01-06T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-07T00:00:00","2015-01-07T00:00:00","2015-01-07T00:00:00","2015-01-07T00:00:00","2015-01-07T00:00:00","2015-01-09T00:00:00","2015-01-09T00:00:00","2015-01-09T00:00:00","2015-01-09T00:00:00","2015-01-09T00:00:00","2015-01-09T00:00:00","2015-01-12T00:00:00","2015-01-12T00:00:00","2015-01-12T00:00:00","2015-01-12T00:00:00","2015-01-12T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-13T00:00:00","2015-01-13T00:00:00","2015-01-13T00:00:00","2015-01-13T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-14T00:00:00","2015-01-14T00:00:00","2015-01-14T00:00:00","2015-01-14T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-15T00:00:00","2015-01-15T00:00:00","2015-01-15T00:00:00","2015-01-15T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-16T00:00:00","2015-01-16T00:00:00","2015-01-16T00:00:00","2015-01-16T00:00:00","2015-01-16T00:00:00","2015-01-19T00:00:00","2015-01-19T00:00:00","2015-01-19T00:00:00","2015-01-19T00:00:00","2015-01-19T00:00:00","2015-01-19T00:00:00","2015-02-02T00:00:00","2015-02-02T00:00:00","2015-02-02T00:00:00","2015-02-02T00:00:00","2015-02-02T00:00:00","2015-02-02T00:00:00","2015-02-03T00:00:00","2015-02-03T00:00:00","2015-02-03T00:00:00","2015-02-03T00:00:00","2015-02-03T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-04T00:00:00","2015-02-04T00:00:00","2015-02-04T00:00:00","2015-02-04T00:00:00","2015-02-04T00:00:00","2015-02-09T00:00:00","2015-02-09T00:00:00","2015-02-09T00:00:00","2015-02-09T00:00:00","2015-02-09T00:00:00","2015-02-09T00:00:00","2015-02-10T00:00:00","2015-02-10T00:00:00","2015-02-10T00:00:00","2015-02-10T00:00:00","2015-02-10T00:00:00","2015-02-10T00:00:00","2015-02-12T00:00:00","2015-02-12T00:00:00","2015-02-12T00:00:00","2015-02-12T00:00:00","2015-02-12T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-13T00:00:00","2015-02-13T00:00:00","2015-02-13T00:00:00","2015-02-13T00:00:00","2015-02-13T00:00:00","2015-02-16T00:00:00","2015-02-16T00:00:00","2015-02-16T00:00:00","2015-02-16T00:00:00","2015-02-16T00:00:00","2015-02-16T00:00:00","2015-02-18T00:00:00","2015-02-18T00:00:00","2015-02-18T00:00:00","2015-02-18T00:00:00","2015-02-18T00:00:00","2015-02-18T00:00:00","2015-02-23T00:00:00","2015-02-23T00:00:00","2015-02-23T00:00:00","2015-02-23T00:00:00","2015-02-23T00:00:00","2015-02-23T00:00:00","2015-02-27T00:00:00","2015-02-27T00:00:00","2015-02-27T00:00:00","2015-02-27T00:00:00","2015-02-27T00:00:00","2015-02-27T00:00:00","2015-03-04T00:00:00","2015-03-04T00:00:00","2015-03-04T00:00:00","2015-03-04T00:00:00","2015-03-04T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-05T00:00:00","2015-03-05T00:00:00","2015-03-05T00:00:00","2015-03-05T00:00:00","2015-03-05T00:00:00","2015-03-10T00:00:00","2015-03-10T00:00:00","2015-03-10T00:00:00","2015-03-10T00:00:00","2015-03-10T00:00:00","2015-03-10T00:00:00","2015-0 ...
